# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
csv_path = Path(r"C:\Users\quint\Downloads\Project 1 Data Sets\NCHS_-_Leading_Causes_of_Death__United_States_20240411.csv")
death_df = pd.read_csv(csv_path)
death_df.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8

# %%
#Grabbing all causes of death
causename_column = death_df["Cause Name"]
unique_names = causename_column.unique()
print(unique_names)
# Out:
# ['Unintentional injuries' 'All causes' "Alzheimer's disease" 'Stroke'
#  'CLRD' 'Diabetes' 'Heart disease' 'Influenza and pneumonia' 'Suicide'
#  'Cancer' 'Kidney disease']

# %%
#Checking what the total amount for deaths of heart disease to compare in first graph
heart_disease_df = death_df.loc[(death_df["Cause Name"].str.contains("Heart disease")) & (death_df["State"] == "United States")]
sum_hd_df = heart_disease_df["Deaths"].sum()
print(sum_hd_df)
# Out:
# 12222640

# %%
#bar graph showing total deaths per cause over entire dataframe
us_df = death_df[(death_df["State"] == "United States") & 
                 (death_df['Year'].between(1999, 2017))]
us_df = us_df[us_df['Cause Name'] != "All causes"]
cause_deaths = us_df.groupby('Cause Name')['Deaths'].sum()
custom_colors = ["goldenrod", "goldenrod", "firebrick","goldenrod", "firebrick", "goldenrod","goldenrod", "goldenrod", "goldenrod", "goldenrod","goldenrod", "goldenrod"]
plt.figure(figsize=(11, 7))
cause_deaths.plot(kind='bar', color= custom_colors)
plt.title('Total Deaths by Cause in the United States (1999-2017)')
plt.xlabel("Cause Name")
plt.ylabel("Total Deaths")
plt.xticks(rotation=45, ha='right')
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()
# plt.savefig('bar_graph.png', format='png', dpi=300)

# %%
us_df = death_df[(death_df["State"] == "United States") & (death_df["Year"].between(1999, 2017))]
us_df = us_df[us_df['Cause Name'] != "All causes"]
cause_deaths = us_df.groupby('Cause Name')['Deaths'].sum()
plt.figure(figsize=(10, 6))
cause_deaths.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors,)
plt.title('Distribution of Causes of Death in the United States (1999-2017)')
plt.ylabel('')
plt.axis('equal')  
plt.tight_layout()
plt.show()
# plt.savefig('pie_chart.png', format='png', bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

from pathlib import Path

national_death_rates_path= Path("NCHS_-_Leading_Causes_of_Death__United_States.csv")
heart_mortality_path=Path("Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County_20240411.csv")

death_rates_data=pd.read_csv(national_death_rates_path)
heart_mortality_data=pd.read_csv(heart_mortality_path)

death_rates_data.head()
# heart_mortality_data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State   Deaths Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169,936                    49.4
# 1  Unintentional injuries        Alabama    2,703                    53.8
# 2  Unintentional injuries         Alaska      436                    63.7
# 3  Unintentional injuries        Arizona    4,184                    56.2
# 4  Unintentional injuries       Arkansas    1,625                    51.8

# %%
heart_disease_rate = death_rates_data.loc[(death_rates_data["Cause Name"]=="Heart disease")&(death_rates_data["State"]=="United States")]
heart_disease_rate.head()
# Out:
#       Year                               113 Cause Name     Cause Name  \
# 312   2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 929   2016  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 1501  2015  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2074  2014  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2648  2013  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#               State   Deaths Age-adjusted Death Rate
# 312   United States  647,457                   165.0
# 929   United States  635,260                   165.5
# 1501  United States  633,842                   168.5
# 2074  United States  614,348                   167.0
# 2648  United States  611,105                   169.8

# %%
# heart_disease_rate.dtypes

# %%
heart_disease_rate["Deaths"]= heart_disease_rate["Deaths"].str.replace(",","").astype(float)
heart_disease_rate.head()
# Out:
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/4098109997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_disease_rate["Deaths"]= heart_disease_rate["Deaths"].str.replace(",","").astype(float)
#       Year                               113 Cause Name     Cause Name  \
# 312   2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 929   2016  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 1501  2015  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2074  2014  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2648  2013  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#               State    Deaths Age-adjusted Death Rate
# 312   United States  647457.0                   165.0
# 929   United States  635260.0                   165.5
# 1501  United States  633842.0                   168.5
# 2074  United States  614348.0                   167.0
# 2648  United States  611105.0                   169.8

# %%
heart_x= heart_disease_rate["Year"]
heart_y= heart_disease_rate["Deaths"]

plt.figure(facecolor="lavender")
plt.scatter(heart_x,heart_y, color= "pink")

plt.xlabel("Year")
plt.ylabel("Number of Deaths", fontsize="small")
plt.title("Number of Deaths from Heart Disease in the US from 1999-2017")

plt.xlim(1999,2017)
plt.xticks(range(1999,2018,1))
plt.xticks(rotation=45, fontsize="small")

plt.yticks(range(600000,750000,15000), fontsize="small")

slope, intercept, rvalue, p_value, std_err =linregress(heart_x, heart_y)
correlation_coefficient=heart_x.corr(heart_y)
plt.plot(heart_x, slope* heart_x +intercept,color="blue")
# plt.text(2007,660000,f"slope= {slope:.2f}", color="blue")
plt.savefig("US_Mortality.png",format="png")

# %%
illinois_rates=death_rates_data.loc[(death_rates_data["Cause Name"]=="Heart disease")&(death_rates_data["State"]=="Illinois")]
illinois_rates.head()
# Out:
#       Year                               113 Cause Name     Cause Name  \
# 326   2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 898   2016  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 1470  2015  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2043  2014  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2617  2013  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#          State  Deaths Age-adjusted Death Rate
# 326   Illinois  25,394                   163.3
# 898   Illinois  25,013                   165.7
# 1470  Illinois  25,652                   171.5
# 2043  Illinois  25,024                   169.7
# 2617  Illinois  24,839                   170.9

# %%
illinois_rates["Deaths"]= illinois_rates["Deaths"].str.replace(",","").astype(float)
illinois_rates
# Out:
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/4285511440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois_rates["Deaths"]= illinois_rates["Deaths"].str.replace(",","").astype(float)
#        Year                               113 Cause Name     Cause Name  \
# 326    2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 898    2016  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 1470   2015  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2043   2014  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2617   2013  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 3189   2012  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 3762   2011  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 4334   2010  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 4922   2009  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 5496   2008  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 6045   2007  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 6617   2006  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 7189   2005  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 7761   2004  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 8333   2003  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 8905   2002  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 9477   2001  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10049  2000  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10621  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#           State   Deaths Age-adjusted Death Rate
# 326    Illinois  25394.0                   163.3
# 898    Illinois  25013.0                   165.7
# 1470   Illinois  25652.0                   171.5
# 2043   Illinois  25024.0                   169.7
# 2617   Illinois  24839.0                   170.9
# 3189   Illinois  24667.0                   172.7
# 3762   Illinois  24987.0                   178.1
# 4334   Illinois  24959.0                   181.7
# 4922   Illinois  24931.0                   184.0
# 5496   Illinois  26078.0                   195.1
# 6045   Illinois  25813.0                   196.0
# 6617   Illinois  27007.0                   208.5
# 7189   Illinois  28226.0                   220.7
# 7761   Illinois  28284.0                   224.3
# 8333   Illinois  29816.0                   239.2
# 8905   Illinois  30821.0                   250.2
# 9477   Illinois  30990.0                   253.8
# 10049  Illinois  31844.0                   263.7
# 10621  Illinois  33387.0                   279.1

# %%
il_x= illinois_rates["Year"]
il_y= illinois_rates["Deaths"]

plt.figure(facecolor="lavender")
plt.scatter(il_x,il_y, color="pink")
plt.xlabel("Year")
plt.ylabel("Number of Deaths")
plt.title("Number of Deaths from Heart Disease in Illinois from 1999-2017")

plt.xlim(1999,2017)
plt.xticks(range(1999,2017,1))
plt.xticks(rotation=45, fontsize="small")

plt.ylim(20000,35000)
plt.yticks(range(20000,35000,1000))
plt.yticks(fontsize="small")

slope, intercept, rvalue, p_value, std_err =linregress(il_x, il_y)
correlation_coefficient=il_x.corr(il_y)
plt.plot(il_x, slope* il_x +intercept,color="blue")
# plt.text(2007,28000,f"Slope= {slope:.2f}", color="blue")
plt.savefig("IL_Mortality.png",format="png")

# %%
state_rate_start=death_rates_data.loc[(death_rates_data["Cause Name"]=="Heart disease")&(death_rates_data["Year"]==1999)&(death_rates_data["State"]!="United States")]
state_rate_start
# Out:
#        Year                               113 Cause Name     Cause Name  \
# 10608  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10609  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10610  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10611  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10612  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10613  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10614  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10615  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10616  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10617  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10618  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10619  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10620  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10621  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10622  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10623  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10624  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10625  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10626  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10627  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10628  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10629  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10630  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10631  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10632  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10633  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10634  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10635  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10636  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10637  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10638  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10639  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10640  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10641  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10642  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10643  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10644  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10645  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10646  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10647  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10648  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10649  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10650  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10651  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10653  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10654  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10655  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10656  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10657  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10658  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10659  1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#                       State  Deaths Age-adjusted Death Rate
# 10608               Alabama  13,419                   303.0
# 10609                Alaska     563                   198.0
# 10610               Arizona  10,800                   223.1
# 10611              Arkansas   8,315                   287.8
# 10612            California  71,930                   257.3
# 10613              Colorado   6,420                   196.3
# 10614           Connecticut   9,127                   238.8
# 10615              Delaware   2,011                   269.2
# 10616  District of Columbia   1,652                   296.2
# 10617               Florida  51,434                   247.7
# 10618               Georgia  17,597                   282.8
# 10619                Hawaii   2,410                   201.7
# 10620                 Idaho   2,532                   220.5
# 10621              Illinois  33,387                   279.1
# 10622               Indiana  16,661                   282.5
# 10623                  Iowa   8,699                   240.3
# 10624                Kansas   6,975                   237.0
# 10625              Kentucky  12,098                   310.9
# 10626             Louisiana  12,007                   302.3
# 10627                 Maine   3,418                   238.7
# 10628              Maryland  12,080                   259.2
# 10629         Massachusetts  15,871                   228.5
# 10630              Michigan  27,693                   292.9
# 10631             Minnesota   9,533                   192.4
# 10632           Mississippi   9,336                   347.4
# 10633              Missouri  17,974                   300.5
# 10634               Montana   2,049                   214.6
# 10635              Nebraska   4,497                   235.0
# 10636                Nevada   4,231                   274.3
# 10637         New Hampshire   2,751                   236.2
# 10638            New Jersey  23,493                   270.5
# 10639            New Mexico   3,452                   218.0
# 10640              New York  58,987                   306.1
# 10641        North Carolina  19,191                   260.9
# 10642          North Dakota   1,833                   234.2
# 10643                  Ohio  33,192                   285.7
# 10644              Oklahoma  11,263                   316.1
# 10645                Oregon   7,263                   205.7
# 10646          Pennsylvania  41,707                   281.7
# 10647          Rhode Island   3,008                   244.1
# 10648        South Carolina   9,981                   273.4
# 10649          South Dakota   2,024                   228.6
# 10650             Tennessee  16,280                   299.0
# 10651                 Texas  43,418                   270.1
# 10653                  Utah   2,786                   190.1
# 10654               Vermont   1,342                   217.4
# 10655              Virginia  15,329                   250.9
# 10656            Washington  11,515                   215.7
# 10657         West Virginia   6,822                   325.5
# 10658             Wisconsin  13,827                   243.7
# 10659               Wyoming   1,009                   227.8

# %%
state_rate_last=death_rates_data.loc[(death_rates_data["Cause Name"]=="Heart disease")&(death_rates_data["Year"]==2017)&(death_rates_data["State"]!= "United States")]
state_rate_last
# state_rate_last.count()
# Out:
#      Year                               113 Cause Name     Cause Name  \
# 313  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 314  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 315  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 316  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 317  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 318  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 319  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 320  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 321  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 322  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 323  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 324  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 325  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 326  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 327  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 328  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 329  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 330  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 331  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 332  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 333  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 334  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 335  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 336  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 337  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 338  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 339  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 340  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 341  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 342  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 343  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 344  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 345  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 346  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 347  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 348  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 349  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 350  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 351  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 352  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 353  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 354  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 355  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 356  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 357  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 358  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 359  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 360  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 361  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 362  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 363  2017  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#                     State  Deaths Age-adjusted Death Rate
# 313               Alabama  13,110                   223.2
# 314                Alaska     814                   135.0
# 315               Arizona  12,398                   141.9
# 316              Arkansas   8,270                   223.8
# 317            California  62,797                   142.9
# 318              Colorado   7,060                   122.7
# 319           Connecticut   7,138                   141.6
# 320              Delaware   1,990                   158.4
# 321  District of Columbia   1,284                   189.8
# 322               Florida  46,440                   145.8
# 323               Georgia  18,389                   175.8
# 324                Hawaii   2,575                   129.8
# 325                 Idaho   3,084                   162.5
# 326              Illinois  25,394                   163.3
# 327               Indiana  14,445                   183.2
# 328                  Iowa   7,180                   167.4
# 329                Kansas   5,723                   158.0
# 330              Kentucky  10,343                   195.9
# 331             Louisiana  11,260                   214.4
# 332                 Maine   2,844                   143.5
# 333              Maryland  11,653                   164.5
# 334         Massachusetts  12,140                   134.7
# 335              Michigan  25,187                   196.1
# 336             Minnesota   8,230                   119.1
# 337           Mississippi   7,944                   231.6
# 338              Missouri  14,820                   191.1
# 339               Montana   2,164                   155.0
# 340              Nebraska   3,581                   149.3
# 341                Nevada   6,417                   199.3
# 342         New Hampshire   2,721                   149.7
# 343            New Jersey  18,840                   162.3
# 344            New Mexico   3,896                   151.4
# 345              New York  44,092                   171.2
# 346        North Carolina  18,808                   156.5
# 347          North Dakota   1,326                   137.8
# 348                  Ohio  28,008                   186.2
# 349              Oklahoma  10,772                   237.2
# 350                Oregon   6,942                   134.0
# 351          Pennsylvania  32,312                   176.0
# 352          Rhode Island   2,339                   155.7
# 353        South Carolina  10,418                   172.0
# 354          South Dakota   1,710                   150.1
# 355             Tennessee  16,019                   202.2
# 356                 Texas  45,346                   169.2
# 357                  Utah   3,749                   150.2
# 358               Vermont   1,332                   152.5
# 359              Virginia  14,861                   154.5
# 360            Washington  11,582                   138.8
# 361         West Virginia   4,849                   192.0
# 362             Wisconsin  11,860                   157.6
# 363               Wyoming   1,001                   148.9

# %%
percent_change=pd.merge(state_rate_start,state_rate_last, how="left", on=("State","Cause Name","113 Cause Name"), suffixes=("_1999","_2017"))
percent_change
# Out:
#     Year_1999                               113 Cause Name     Cause Name  \
# 0        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 1        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 2        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 3        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 4        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 5        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 6        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 7        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 8        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 9        1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 10       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 11       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 12       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 13       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 14       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 15       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 16       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 17       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 18       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 19       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 20       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 21       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 22       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 23       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 24       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 25       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 26       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 27       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 28       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 29       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 30       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 31       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 32       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 33       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 34       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 35       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 36       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 37       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 38       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 39       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 40       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 41       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 42       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 43       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 44       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 45       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 46       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 47       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 48       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 49       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
# 50       1999  Diseases of heart (I00-I09,I11,I13,I20-I51)  Heart disease
#
#                    State Deaths_1999 Age-adjusted Death Rate_1999  Year_2017  \
# 0                Alabama      13,419                        303.0       2017
# 1                 Alaska         563                        198.0       2017
# 2                Arizona      10,800                        223.1       2017
# 3               Arkansas       8,315                        287.8       2017
# 4             California      71,930                        257.3       2017
# 5               Colorado       6,420                        196.3       2017
# 6            Connecticut       9,127                        238.8       2017
# 7               Delaware       2,011                        269.2       2017
# 8   District of Columbia       1,652                        296.2       2017
# 9                Florida      51,434                        247.7       2017
# 10               Georgia      17,597                        282.8       2017
# 11                Hawaii       2,410                        201.7       2017
# 12                 Idaho       2,532                        220.5       2017
# 13              Illinois      33,387                        279.1       2017
# 14               Indiana      16,661                        282.5       2017
# 15                  Iowa       8,699                        240.3       2017
# 16                Kansas       6,975                        237.0       2017
# 17              Kentucky      12,098                        310.9       2017
# 18             Louisiana      12,007                        302.3       2017
# 19                 Maine       3,418                        238.7       2017
# 20              Maryland      12,080                        259.2       2017
# 21         Massachusetts      15,871                        228.5       2017
# 22              Michigan      27,693                        292.9       2017
# 23             Minnesota       9,533                        192.4       2017
# 24           Mississippi       9,336                        347.4       2017
# 25              Missouri      17,974                        300.5       2017
# 26               Montana       2,049                        214.6       2017
# 27              Nebraska       4,497                        235.0       2017
# 28                Nevada       4,231                        274.3       2017
# 29         New Hampshire       2,751                        236.2       2017
# 30            New Jersey      23,493                        270.5       2017
# 31            New Mexico       3,452                        218.0       2017
# 32              New York      58,987                        306.1       2017
# 33        North Carolina      19,191                        260.9       2017
# 34          North Dakota       1,833                        234.2       2017
# 35                  Ohio      33,192                        285.7       2017
# 36              Oklahoma      11,263                        316.1       2017
# 37                Oregon       7,263                        205.7       2017
# 38          Pennsylvania      41,707                        281.7       2017
# 39          Rhode Island       3,008                        244.1       2017
# 40        South Carolina       9,981                        273.4       2017
# 41          South Dakota       2,024                        228.6       2017
# 42             Tennessee      16,280                        299.0       2017
# 43                 Texas      43,418                        270.1       2017
# 44                  Utah       2,786                        190.1       2017
# 45               Vermont       1,342                        217.4       2017
# 46              Virginia      15,329                        250.9       2017
# 47            Washington      11,515                        215.7       2017
# 48         West Virginia       6,822                        325.5       2017
# 49             Wisconsin      13,827                        243.7       2017
# 50               Wyoming       1,009                        227.8       2017
#
#    Deaths_2017 Age-adjusted Death Rate_2017
# 0       13,110                        223.2
# 1          814                        135.0
# 2       12,398                        141.9
# 3        8,270                        223.8
# 4       62,797                        142.9
# 5        7,060                        122.7
# 6        7,138                        141.6
# 7        1,990                        158.4
# 8        1,284                        189.8
# 9       46,440                        145.8
# 10      18,389                        175.8
# 11       2,575                        129.8
# 12       3,084                        162.5
# 13      25,394                        163.3
# 14      14,445                        183.2
# 15       7,180                        167.4
# 16       5,723                        158.0
# 17      10,343                        195.9
# 18      11,260                        214.4
# 19       2,844                        143.5
# 20      11,653                        164.5
# 21      12,140                        134.7
# 22      25,187                        196.1
# 23       8,230                        119.1
# 24       7,944                        231.6
# 25      14,820                        191.1
# 26       2,164                        155.0
# 27       3,581                        149.3
# 28       6,417                        199.3
# 29       2,721                        149.7
# 30      18,840                        162.3
# 31       3,896                        151.4
# 32      44,092                        171.2
# 33      18,808                        156.5
# 34       1,326                        137.8
# 35      28,008                        186.2
# 36      10,772                        237.2
# 37       6,942                        134.0
# 38      32,312                        176.0
# 39       2,339                        155.7
# 40      10,418                        172.0
# 41       1,710                        150.1
# 42      16,019                        202.2
# 43      45,346                        169.2
# 44       3,749                        150.2
# 45       1,332                        152.5
# 46      14,861                        154.5
# 47      11,582                        138.8
# 48       4,849                        192.0
# 49      11,860                        157.6
# 50       1,001                        148.9

# %%
# cleaning up df to only include values wanted
filtered_df=percent_change[["Cause Name","State", "Deaths_1999","Deaths_2017"]]

filtered_df["Deaths_1999"]= filtered_df["Deaths_1999"].str.replace(",","").astype(float)
filtered_df["Deaths_2017"]= filtered_df["Deaths_2017"].str.replace(",","").astype(float)
filtered_df
# Out:
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/587480348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Deaths_1999"]= filtered_df["Deaths_1999"].str.replace(",","").astype(float)
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/587480348.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Deaths_2017"]= filtered_df["Deaths_2017"].str.replace(",","").astype(float)
#        Cause Name                 State  Deaths_1999  Deaths_2017
# 0   Heart disease               Alabama      13419.0      13110.0
# 1   Heart disease                Alaska        563.0        814.0
# 2   Heart disease               Arizona      10800.0      12398.0
# 3   Heart disease              Arkansas       8315.0       8270.0
# 4   Heart disease            California      71930.0      62797.0
# 5   Heart disease              Colorado       6420.0       7060.0
# 6   Heart disease           Connecticut       9127.0       7138.0
# 7   Heart disease              Delaware       2011.0       1990.0
# 8   Heart disease  District of Columbia       1652.0       1284.0
# 9   Heart disease               Florida      51434.0      46440.0
# 10  Heart disease               Georgia      17597.0      18389.0
# 11  Heart disease                Hawaii       2410.0       2575.0
# 12  Heart disease                 Idaho       2532.0       3084.0
# 13  Heart disease              Illinois      33387.0      25394.0
# 14  Heart disease               Indiana      16661.0      14445.0
# 15  Heart disease                  Iowa       8699.0       7180.0
# 16  Heart disease                Kansas       6975.0       5723.0
# 17  Heart disease              Kentucky      12098.0      10343.0
# 18  Heart disease             Louisiana      12007.0      11260.0
# 19  Heart disease                 Maine       3418.0       2844.0
# 20  Heart disease              Maryland      12080.0      11653.0
# 21  Heart disease         Massachusetts      15871.0      12140.0
# 22  Heart disease              Michigan      27693.0      25187.0
# 23  Heart disease             Minnesota       9533.0       8230.0
# 24  Heart disease           Mississippi       9336.0       7944.0
# 25  Heart disease              Missouri      17974.0      14820.0
# 26  Heart disease               Montana       2049.0       2164.0
# 27  Heart disease              Nebraska       4497.0       3581.0
# 28  Heart disease                Nevada       4231.0       6417.0
# 29  Heart disease         New Hampshire       2751.0       2721.0
# 30  Heart disease            New Jersey      23493.0      18840.0
# 31  Heart disease            New Mexico       3452.0       3896.0
# 32  Heart disease              New York      58987.0      44092.0
# 33  Heart disease        North Carolina      19191.0      18808.0
# 34  Heart disease          North Dakota       1833.0       1326.0
# 35  Heart disease                  Ohio      33192.0      28008.0
# 36  Heart disease              Oklahoma      11263.0      10772.0
# 37  Heart disease                Oregon       7263.0       6942.0
# 38  Heart disease          Pennsylvania      41707.0      32312.0
# 39  Heart disease          Rhode Island       3008.0       2339.0
# 40  Heart disease        South Carolina       9981.0      10418.0
# 41  Heart disease          South Dakota       2024.0       1710.0
# 42  Heart disease             Tennessee      16280.0      16019.0
# 43  Heart disease                 Texas      43418.0      45346.0
# 44  Heart disease                  Utah       2786.0       3749.0
# 45  Heart disease               Vermont       1342.0       1332.0
# 46  Heart disease              Virginia      15329.0      14861.0
# 47  Heart disease            Washington      11515.0      11582.0
# 48  Heart disease         West Virginia       6822.0       4849.0
# 49  Heart disease             Wisconsin      13827.0      11860.0
# 50  Heart disease               Wyoming       1009.0       1001.0

# %%
# Code was written with help from ChatGPT and references from course materials

# Convert "Deaths_1999" and "Deaths_2017" columns to numeric
filtered_df["Deaths_1999"] = pd.to_numeric(filtered_df["Deaths_1999"])
filtered_df["Deaths_2017"] = pd.to_numeric(filtered_df["Deaths_2017"])

# Initialize list to store percent changes
percent_changes = []

# Calculate percent change for each row
for index, row in filtered_df.iterrows():
    deaths_1999 = row["Deaths_1999"]
    deaths_2017 = row["Deaths_2017"]
    
    # just in case numbers contain 0, 
    if deaths_1999 != 0:
        percent_change_value = ((deaths_2017 - deaths_1999) / deaths_1999) * 100
    else:
        percent_change_value = None  # Set to None if deaths_1999 is zero
        
    percent_changes.append(percent_change_value)

# Add "Percent Change" column to DataFrame
filtered_df["Percent Change"] = percent_changes

filtered_df["Percent Change"] = filtered_df["Percent Change"].map("{:.2f}".format)
# Display DataFrame
filtered_df.head()
# Out:
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/285959706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Deaths_1999"] = pd.to_numeric(filtered_df["Deaths_1999"])
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/285959706.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Deaths_2017"] = pd.to_numeric(filtered_df["Deaths_2017"])
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/285959706.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Percent Change"] = percent_changes
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/285959706.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Percent Change"] = filtered_df["Percent Change"].map("{:.2f}".format)
#       Cause Name       State  Deaths_1999  Deaths_2017 Percent Change
# 0  Heart disease     Alabama      13419.0      13110.0          -2.30
# 1  Heart disease      Alaska        563.0        814.0          44.58
# 2  Heart disease     Arizona      10800.0      12398.0          14.80
# 3  Heart disease    Arkansas       8315.0       8270.0          -0.54
# 4  Heart disease  California      71930.0      62797.0         -12.70

# %%
filtered_df['Percent Change'] = pd.to_numeric(filtered_df['Percent Change'])

# Define categories (states) and values (percent changes)
states = filtered_df["State"]
values = filtered_df["Percent Change"]

# code was written with help from chatgpt
colors = ['green' if v >= 0 else 'red' for v in values]


plt.figure(figsize=(12, 8)) 
bars = plt.bar(states, values, color=colors)


plt.xlabel('State', fontsize=12)
plt.ylabel('Percent Change (%)', fontsize=10)
plt.title('Percent Change of Heart Disease Mortality Across the US From 1999-2017', fontsize=14)

# Customize colors in legend, code written with help from chatgpt to include a negative y axis
positive_bar = plt.Line2D([0], [0], color='green', linewidth=4)
negative_bar = plt.Line2D([0], [0], color='red', linewidth=4)
plt.legend([positive_bar, negative_bar], ['Positive', 'Negative'], loc='upper right')

# formatting to add values in text on bars, code written with help from chatgpt
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', ha='center', va='bottom' if yval >= 0 else 'top', fontsize="x-small")

# Show the plot
plt.grid(True)
plt.xticks(rotation=90)
plt.tight_layout()

plt.savefig("Percent_Change.png", format="png")
# Out:
# /var/folders/2k/_5w54ms57s354pk985m8f6fr0000gn/T/ipykernel_37323/2114129900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Percent Change'] = pd.to_numeric(filtered_df['Percent Change'])

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Getting CSVs into DataFrames
death_df=pd.read_csv("Causes of Death.csv")
heart_df=pd.read_csv("Heart Disease Data.csv")
# Looking at each data set
display(death_df.head())
heart_df.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State   Deaths Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169,936                    49.4
# 1  Unintentional injuries        Alabama    2,703                    53.8
# 2  Unintentional injuries         Alaska      436                    63.7
# 3  Unintentional injuries        Arizona    4,184                    56.2
# 4  Unintentional injuries       Arkansas    1,625                    51.8
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2014           AK  Aleutians East          County       NVSS
# 1  2014           AK  Aleutians West          County       NVSS
# 2  2014           AK       Anchorage          County       NVSS
# 3  2014           AK          Bethel          County       NVSS
# 4  2014           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       105.3
# 1  Cardiovascular Diseases  Heart Disease Mortality       211.9
# 2  Cardiovascular Diseases  Heart Disease Mortality       257.9
# 3  Cardiovascular Diseases  Heart Disease Mortality       351.6
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 3  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 4  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# 0                        NaN                 NaN                  Gender
# 1                        NaN                 NaN                  Gender
# 2                        NaN                 NaN                  Gender
# 3                        NaN                 NaN                  Gender
# 4                          ~   Insufficient Data                  Gender
#
#   Stratification1 StratificationCategory2 Stratification2 TopicID  LocationID  \
# 0         Overall          Race/Ethnicity         Overall      T2        2013
# 1         Overall          Race/Ethnicity         Overall      T2        2016
# 2         Overall          Race/Ethnicity         Overall      T2        2020
# 3         Overall          Race/Ethnicity         Overall      T2        2050
# 4         Overall          Race/Ethnicity         Overall      T2        2060
#
#                  Location 1
# 0  (55.440626, -161.962562)
# 1  (52.995403, -170.251538)
# 2  (61.159049, -149.103905)
# 3  (60.924483, -159.749655)
# 4  (58.754192, -156.694709)

# %%
#Dropping 113 Cause Name, will use Cause Name column for analysis
death_df=death_df.drop("113 Cause Name",axis=1)
death_df.head()
# Out:
#    Year              Cause Name          State   Deaths  \
# 0  2017  Unintentional injuries  United States  169,936
# 1  2017  Unintentional injuries        Alabama    2,703
# 2  2017  Unintentional injuries         Alaska      436
# 3  2017  Unintentional injuries        Arizona    4,184
# 4  2017  Unintentional injuries       Arkansas    1,625
#
#   Age-adjusted Death Rate
# 0                    49.4
# 1                    53.8
# 2                    63.7
# 3                    56.2
# 4                    51.8

# %%
# Filtering to All Causes because want overall Death Rate
allcauses_df=death_df[death_df["Cause Name"]=="All causes"]
allcauses_df
# Out:
#        Year  Cause Name          State     Deaths Age-adjusted Death Rate
# 52     2017  All causes  United States  2,813,503                   731.9
# 53     2017  All causes        Alabama     53,238                   917.7
# 54     2017  All causes         Alaska      4,411                   708.8
# 55     2017  All causes        Arizona     57,758                   678.5
# 56     2017  All causes       Arkansas     32,588                   900.1
# ...     ...         ...            ...        ...                     ...
# 10395  1999  All causes       Virginia     55,320                   889.6
# 10396  1999  All causes     Washington     43,865                   815.1
# 10397  1999  All causes  West Virginia     21,049                1,012.30
# 10398  1999  All causes      Wisconsin     46,672                   831.5
# 10399  1999  All causes        Wyoming      4,042                   895.4
#
# [988 rows x 5 columns]

# %%
#Filtering to Only State Data
droprows=allcauses_df["State"] != "United States"
filtered_df=allcauses_df[droprows]
filtered_df
# Out:
#        Year  Cause Name          State   Deaths Age-adjusted Death Rate
# 53     2017  All causes        Alabama   53,238                   917.7
# 54     2017  All causes         Alaska    4,411                   708.8
# 55     2017  All causes        Arizona   57,758                   678.5
# 56     2017  All causes       Arkansas   32,588                   900.1
# 57     2017  All causes     California  268,189                   618.7
# ...     ...         ...            ...      ...                     ...
# 10395  1999  All causes       Virginia   55,320                   889.6
# 10396  1999  All causes     Washington   43,865                   815.1
# 10397  1999  All causes  West Virginia   21,049                1,012.30
# 10398  1999  All causes      Wisconsin   46,672                   831.5
# 10399  1999  All causes        Wyoming    4,042                   895.4
#
# [969 rows x 5 columns]

# %%
# Making death rate column numeric
filtered_df["Age-adjusted Death Rate"]=pd.to_numeric(filtered_df['Age-adjusted Death Rate'], errors='coerce')
# Grouping for Bar Chart
avg_mortality=filtered_df.groupby('State')['Age-adjusted Death Rate'].mean().sort_values(ascending=False)
# Bar Chart of Average Mortality Rates
plt.bar(avg_mortality.head(10).index,avg_mortality.head(10))
plt.title('States with Highest Average Mortality Rates From 1999-2017')
plt.xlabel('States')
plt.ylabel('Average Mortality Rate')
plt.xticks(rotation=45, ha='right')
plt.ylim(850,max(avg_mortality)+10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ssark\AppData\Local\Temp\ipykernel_23372\473975584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Age-adjusted Death Rate"]=pd.to_numeric(filtered_df['Age-adjusted Death Rate'], errors='coerce')

# %%
# Getting US Heat Map with help from Google Gemini
us_map = gpd.read_file('gz_2010_us_040_00_500k.json')
merged_map = us_map.merge(avg_mortality.reset_index(), left_on='NAME', right_on='State')
cmap = plt.cm.RdGy
fig, ax = plt.subplots(figsize=(22, 10))
merged_map.plot(column='Age-adjusted Death Rate', ax=ax, cmap=cmap, legend=True)
plt.title('Average Death Rate by State (1999-2017)')
ax.set_axis_off()
plt.xlim(-200,0)

# Show the plot
plt.show()

# %%
heartdisease_df=death_df[death_df["Cause Name"]=="Heart disease"]
heartdisease_df.head()
# Out:
#      Year     Cause Name          State   Deaths Age-adjusted Death Rate
# 312  2017  Heart disease  United States  647,457                     165
# 313  2017  Heart disease        Alabama   13,110                   223.2
# 314  2017  Heart disease         Alaska      814                     135
# 315  2017  Heart disease        Arizona   12,398                   141.9
# 316  2017  Heart disease       Arkansas    8,270                   223.8

# %%
droprows2=heartdisease_df["State"] != "United States"
heartfiltered_df=heartdisease_df[droprows2]
heartfiltered_df.head()
# Out:
#      Year     Cause Name       State  Deaths Age-adjusted Death Rate
# 313  2017  Heart disease     Alabama  13,110                   223.2
# 314  2017  Heart disease      Alaska     814                     135
# 315  2017  Heart disease     Arizona  12,398                   141.9
# 316  2017  Heart disease    Arkansas   8,270                   223.8
# 317  2017  Heart disease  California  62,797                   142.9

# %%
# Making death rate column numeric
heartfiltered_df["Age-adjusted Death Rate"]=pd.to_numeric(heartfiltered_df['Age-adjusted Death Rate'], errors='coerce')
# Grouping for Bar Chart
heart_mortality =heartfiltered_df.groupby('State')['Age-adjusted Death Rate'].mean().sort_values(ascending=False)
# Bar Chart of Average Heart Attack Mortality Rates
plt.bar(heart_mortality.head(10).index,heart_mortality.head(10))
plt.title('States with Highest Average Heart Disease Mortality Rates From 1999-2017')
plt.xlabel('States')
plt.ylabel('Average Heart Disease Mortality Rate')
plt.xticks(rotation=45, ha='right')
plt.ylim(220,max(heart_mortality)+10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ssark\AppData\Local\Temp\ipykernel_23372\4212709129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heartfiltered_df["Age-adjusted Death Rate"]=pd.to_numeric(heartfiltered_df['Age-adjusted Death Rate'], errors='coerce')

# %%
merged_map = us_map.merge(heart_mortality.reset_index(), left_on='NAME', right_on='State')
cmap = plt.cm.RdGy
fig, ax = plt.subplots(figsize=(22, 10))
merged_map.plot(column='Age-adjusted Death Rate', ax=ax, cmap=cmap, legend=True)
plt.title('Average Heart Disease Death Rate by State (1999-2017)')
ax.set_axis_off()
plt.xlim(-200,0)

# Show the plot
plt.show()

# %%
# %matplotlib widget

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path = Path("/Users/cillian/Downloads/NCHS_-_Leading_Causes_of_Death__United_States (1).csv")
death_df = pd.read_csv(csv_path)

death_df.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State   Deaths Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169,936                    49.4
# 1  Unintentional injuries        Alabama    2,703                    53.8
# 2  Unintentional injuries         Alaska      436                    63.7
# 3  Unintentional injuries        Arizona    4,184                    56.2
# 4  Unintentional injuries       Arkansas    1,625                    51.8

# %%
csv_path = Path("/Users/cillian/Downloads/Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County_20240411.csv")
heart_df = pd.read_csv(csv_path)

heart_df.head()
# Out:
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2014           AK  Aleutians East          County       NVSS
# 1  2014           AK  Aleutians West          County       NVSS
# 2  2014           AK       Anchorage          County       NVSS
# 3  2014           AK          Bethel          County       NVSS
# 4  2014           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       105.3
# 1  Cardiovascular Diseases  Heart Disease Mortality       211.9
# 2  Cardiovascular Diseases  Heart Disease Mortality       257.9
# 3  Cardiovascular Diseases  Heart Disease Mortality       351.6
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 3  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 4  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# 0                        NaN                 NaN                  Gender
# 1                        NaN                 NaN                  Gender
# 2                        NaN                 NaN                  Gender
# 3                        NaN                 NaN                  Gender
# 4                          ~   Insufficient Data                  Gender
#
#   Stratification1 StratificationCategory2 Stratification2 TopicID  LocationID  \
# 0         Overall          Race/Ethnicity         Overall      T2        2013
# 1         Overall          Race/Ethnicity         Overall      T2        2016
# 2         Overall          Race/Ethnicity         Overall      T2        2020
# 3         Overall          Race/Ethnicity         Overall      T2        2050
# 4         Overall          Race/Ethnicity         Overall      T2        2060
#
#                  Location 1
# 0  (55.440626, -161.962562)
# 1  (52.995403, -170.251538)
# 2  (61.159049, -149.103905)
# 3  (60.924483, -159.749655)
# 4  (58.754192, -156.694709)

# %%
heart2_df = heart_df.rename(columns=
                            {"LocationAbbr" : "State",
                             "Data_Value" : "Value",
                              "Stratification1" : "Gender",
                               "Stratification2" : "Race/Ethnicity"
                               })
heart2_df.head()
# Out:
#    Year State    LocationDesc GeographicLevel DataSource  \
# 0  2014    AK  Aleutians East          County       NVSS
# 1  2014    AK  Aleutians West          County       NVSS
# 2  2014    AK       Anchorage          County       NVSS
# 3  2014    AK          Bethel          County       NVSS
# 4  2014    AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality  105.3
# 1  Cardiovascular Diseases  Heart Disease Mortality  211.9
# 2  Cardiovascular Diseases  Heart Disease Mortality  257.9
# 3  Cardiovascular Diseases  Heart Disease Mortality  351.6
# 4  Cardiovascular Diseases  Heart Disease Mortality    NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 3  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 4  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# 0                        NaN                 NaN                  Gender
# 1                        NaN                 NaN                  Gender
# 2                        NaN                 NaN                  Gender
# 3                        NaN                 NaN                  Gender
# 4                          ~   Insufficient Data                  Gender
#
#     Gender StratificationCategory2 Race/Ethnicity TopicID  LocationID  \
# 0  Overall          Race/Ethnicity        Overall      T2        2013
# 1  Overall          Race/Ethnicity        Overall      T2        2016
# 2  Overall          Race/Ethnicity        Overall      T2        2020
# 3  Overall          Race/Ethnicity        Overall      T2        2050
# 4  Overall          Race/Ethnicity        Overall      T2        2060
#
#                  Location 1
# 0  (55.440626, -161.962562)
# 1  (52.995403, -170.251538)
# 2  (61.159049, -149.103905)
# 3  (60.924483, -159.749655)
# 4  (58.754192, -156.694709)

# %%
heart3_df = heart2_df[["Year","State","Value","Gender","Race/Ethnicity"]]
heart3_df.head()
# Out:
#    Year State  Value   Gender Race/Ethnicity
# 0  2014    AK  105.3  Overall        Overall
# 1  2014    AK  211.9  Overall        Overall
# 2  2014    AK  257.9  Overall        Overall
# 3  2014    AK  351.6  Overall        Overall
# 4  2014    AK    NaN  Overall        Overall

# %%
heart4_df = heart3_df.loc[(heart3_df["Gender"] == "Male") | (heart3_df["Gender"] == "Female"), :]
heart4_df.head()
# Out:
#     Year State  Value Gender Race/Ethnicity
# 27  2014    AK  347.9   Male        Overall
# 28  2014    AK  332.1   Male        Overall
# 29  2014    AK  489.8   Male        Overall
# 30  2014    AK    NaN   Male        Overall
# 31  2014    AK  401.2   Male        Overall

# %%
heart4_df["Race/Ethnicity"].unique()
# Out:
# array(['Overall', 'White', 'Black', 'Hispanic',
#        'American Indian and Alaskan Native', 'Asian and Pacific Islander'],
#       dtype=object)

# %%
heart5_df = heart4_df.loc[(heart4_df["Race/Ethnicity"] == "White") | (heart4_df["Race/Ethnicity"] == "Black") | (heart4_df["Race/Ethnicity"] == "Hispanic") | (heart4_df["Race/Ethnicity"] == "American Indian and Alaskan Native") | (heart4_df["Race/Ethnicity"] == "Asian and Pacific Islander"), :]
heart5_df
# Out:
#        Year State  Value  Gender              Race/Ethnicity
# 101    2014    AK    NaN    Male                       White
# 102    2014    AK  317.5    Male                       White
# 103    2014    AK    NaN    Male                       White
# 104    2014    AK    NaN    Male                       White
# 105    2014    AK  400.7    Male                       White
# ...     ...   ...    ...     ...                         ...
# 59071  2014    TX    NaN    Male  Asian and Pacific Islander
# 59072  2014    TX    NaN    Male                       Black
# 59073  2014    IA    NaN  Female  Asian and Pacific Islander
# 59074  2014    WV    NaN  Female  Asian and Pacific Islander
# 59075  2014    KS    NaN  Female  Asian and Pacific Islander
#
# [32820 rows x 5 columns]

# %%
heart6_df = heart5_df.dropna(how='any')
heart6_df = heart6_df.set_index("Year")
heart6_df
# Out:
#      State  Value  Gender              Race/Ethnicity
# Year
# 2014    AK  317.5    Male                       White
# 2014    AK  400.7    Male                       White
# 2014    AK  401.0    Male                       White
# 2014    AK  385.5    Male                       White
# 2014    AK  281.6    Male                       White
# ...    ...    ...     ...                         ...
# 2014    IA   45.2    Male                    Hispanic
# 2014    FL  184.3    Male  Asian and Pacific Islander
# 2014    KS  142.3  Female  Asian and Pacific Islander
# 2014    TX  112.0  Female  Asian and Pacific Islander
# 2014    NJ   79.8  Female  Asian and Pacific Islander
#
# [14087 rows x 4 columns]

# %%
females = heart6_df[heart6_df["Gender"] == "Female"]
female_average = females["Value"].mean()
female_average
# Out:
# 274.978471411902

# %%
females["Value"].std()
# Out:
# 105.88712189121081

# %%
males = heart6_df[heart6_df["Gender"] == "Male"]
male_average = males["Value"].mean()
male_average
# Out:
# 424.6979947448486

# %%
males["Value"].std()
# Out:
# 165.34239991296735

# %%
gender_averages = pd.DataFrame({"Female": [275.0], "Male": [424.7]})
gender_averages
# Out:
#    Female   Male
# 0   275.0  424.7

# %%
sum_gen_df = pd.DataFrame({"Gender": ["Female", "Male"], "Value": [275.0, 424.7]})
sum_gen_df
# Out:
#    Gender  Value
# 0  Female  275.0
# 1    Male  424.7

# %%
plt.clf()
plt.figure(figsize=(8, 7))
colors = ["lightpink", "skyblue"]
bars = plt.bar(sum_gen_df["Gender"], sum_gen_df["Value"], color=colors, label=sum_gen_df["Gender"])
#plt.bar(fake_df["Gender"], fake_df["Value"], width = 0.3, align="center", color=colors)
plt.legend(fontsize="x-large")
plt.xlabel("Gender", weight = "bold", fontsize="large")
plt.ylabel("Number of Annual Deaths (out of a 100,000 population)", weight = "bold", fontsize="large")
plt.title("Average Anual Heart Disease Deaths in the US by Gender", weight = "bold", fontsize="x-large")
plt.tick_params(axis='x', which='both', bottom=False, top=False)
plt.gca().set_xticklabels([])
plt.gcf().set_facecolor('burlywood')
plt.gca().set_facecolor('snow')
#std_values = np.array([105.9,165.3])
#plt.errorbar(sum_eth_df["Gender"], sum_eth_df["Value"], yerr=std_values, fmt='none', ecolor='black', capsize=5, label='Std Dev')
plt.tight_layout()
plt.show()
plt.savefig("gender", format="png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
heart6_df["Race/Ethnicity"].value_counts()
# Out:
# Race/Ethnicity
# White                                 6358
# Black                                 3633
# Hispanic                              2107
# Asian and Pacific Islander            1186
# American Indian and Alaskan Native     803
# Name: count, dtype: int64

# %%
white = heart6_df[heart6_df["Race/Ethnicity"] == "White"]
white_average = white["Value"].mean()
white_average
# Out:
# 369.1367411135578

# %%
white["Value"].std()
# Out:
# 121.21771558845361

# %%
black = heart6_df[heart6_df["Race/Ethnicity"] == "Black"]
black_average = black["Value"].mean()
black_average
# Out:
# 438.19295348197085

# %%
black["Value"].std()
# Out:
# 145.71711292360646

# %%
hispanic = heart6_df[heart6_df["Race/Ethnicity"] == "Hispanic"]
hispanic_average = hispanic["Value"].mean()
hispanic_average
# Out:
# 216.82249644043665

# %%
hispanic["Value"].std()
# Out:
# 101.69133859170134

# %%
AIAN = heart6_df[heart6_df["Race/Ethnicity"] == "American Indian and Alaskan Native"]
AIAN_average = AIAN["Value"].mean()
AIAN_average
# Out:
# 441.16674968866755

# %%
API = heart6_df[heart6_df["Race/Ethnicity"] == "Asian and Pacific Islander"]
API_average = API["Value"].mean()
API_average
# Out:
# 173.8746205733558

# %%
ethnicity_averages = pd.DataFrame({"White": [369.1], "Black": [438.2], "Hispanic": [216.8], "American Indian and Alaskan Native": [441.2], "Asian and Pacific Islander": [173.9]})
ethnicity_averages
# Out:
#    White  Black  Hispanic  American Indian and Alaskan Native  \
# 0  369.1  438.2     216.8                               441.2
#
#    Asian and Pacific Islander
# 0                       173.9

# %%
sum_eth_df = pd.DataFrame({"Race/Ethnicity": ["White", "Black", "Hispanic", "American Indian and Alaskan Native", "Asian and Pacific Islander"], "Value": [369.1, 438.2, 216.8, 441.2, 173.9]})
sum_eth_df
# Out:
#                        Race/Ethnicity  Value
# 0                               White  369.1
# 1                               Black  438.2
# 2                            Hispanic  216.8
# 3  American Indian and Alaskan Native  441.2
# 4          Asian and Pacific Islander  173.9

# %%
plt.figure(figsize=(8, 6))
colors = ['lightskyblue', 'lightcoral', 'khaki', 'palegreen', 'plum']
bars = plt.bar(sum_eth_df["Race/Ethnicity"], sum_eth_df["Value"], color=colors, label=sum_eth_df["Race/Ethnicity"])
plt.legend(loc="upper center")
plt.ylim(0, max(sum_eth_df["Value"]) * 1.3)  
plt.ylabel("Number of Annual Deaths (out of a 100,000 population)", weight = "bold")
plt.xlabel("Race/Ethnicity", weight = "bold")
plt.title("Average Anual Heart Disease Deaths in the US by Race/Ethnicity", weight = "bold")
plt.tick_params(axis='x', which='both', bottom=False, top=False)
plt.gca().set_xticklabels([])
plt.gcf().set_facecolor('burlywood')
plt.gca().set_facecolor('snow')
#std_values = np.array([121.2, 145.7, 101.7, 231.1, 76.1])
#plt.errorbar(sum_eth_df["Race/Ethnicity"], sum_eth_df["Value"], yerr=std_values, fmt='none', ecolor='black', capsize=5, label='Std Dev')
plt.tight_layout()
plt.show()
plt.savefig("ethnicity", format="png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
